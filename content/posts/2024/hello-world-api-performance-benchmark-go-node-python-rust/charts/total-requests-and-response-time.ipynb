# %%
import seaborn as sns
import pandas as pd

# %%
data = [
    {"language": "Go", "total_requests": 898131, "avg_rt_ms": 335.77, "min_rt_ms": 1.78, "median_rt_ms": 239.55,
     "max_rt_s": 33.38, "p95_rt_ms": 914.37},
    {"language": "Node", "total_requests": 383091, "avg_rt_ms": 823.61, "min_rt_ms": 2.29, "median_rt_ms": 393.98,
     "max_rt_s": 33.75, "p95_rt_ms": 1410},
    {"language": "Python", "total_requests": 225929, "avg_rt_ms": 1420, "min_rt_ms": 3.15, "median_rt_ms": 861.22,
     "max_rt_s": 35.37, "p95_rt_ms": 1980},
    {"language": "Rust", "total_requests": 901038, "avg_rt_ms": 408.57, "min_rt_ms": 2, "median_rt_ms": 274.13,
     "max_rt_s": 40.77, "p95_rt_ms": 901.35},
]

df = pd.DataFrame(data)
print(df)
# Out:
#   language  total_requests  avg_rt_ms  min_rt_ms  median_rt_ms  max_rt_s  \
# 0       Go          898131     335.77       1.78        239.55     33.38
# 1     Node          383091     823.61       2.29        393.98     33.75
# 2   Python          225929    1420.00       3.15        861.22     35.37
# 3     Rust          901038     408.57       2.00        274.13     40.77
#
#    p95_rt_ms
# 0     914.37
# 1    1410.00
# 2    1980.00
# 3     901.35

# %%
# total requests
df[['language', 'total_requests']].set_index('language').plot(kind="bar")
# Out:
# <Axes: xlabel='language'>

# %%
# min response time
df[['language', 'min_rt_ms']].set_index('language').plot(kind="bar")
# Out:
# <Axes: xlabel='language'>

# %%
# response time
df[['language', 
    'avg_rt_ms',
    'median_rt_ms',
    'p95_rt_ms'
    ]].set_index('language').plot(kind="bar")
# Out:
# <Axes: xlabel='language'>
